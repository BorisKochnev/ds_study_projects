# %% [markdown]
# # Проект "Аналитика маркетинговых инвестиций"
#
# <strong>Описание проекта:</strong> несмотря на огромные вложения в рекламу, последние несколько месяцев компания терпит убытки
#
# <strong>Цель проекта:</strong> разобраться в причинах и помочь компании выйти в плюс

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Загрузка-и-подготовка-данных-к-анализу" data-toc-modified-id="Загрузка-и-подготовка-данных-к-анализу-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Загрузка и подготовка данных к анализу</a></span></li><li><span><a href="#Функции-для-расчета-и-анализа-LTV,-ROI,-удержания-и-конверсии" data-toc-modified-id="Функции-для-расчета-и-анализа-LTV,-ROI,-удержания-и-конверсии-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Функции для расчета и анализа LTV, ROI, удержания и конверсии</a></span></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Выгрузка-пользователей-и-определение-минимальной-и-максимальной-даты-привлечения-пользователей" data-toc-modified-id="Выгрузка-пользователей-и-определение-минимальной-и-максимальной-даты-привлечения-пользователей-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Выгрузка пользователей и определение минимальной и максимальной даты привлечения пользователей</a></span></li><li><span><a href="#Посетители-и-платящие-пользователи-по-странам" data-toc-modified-id="Посетители-и-платящие-пользователи-по-странам-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Посетители и платящие пользователи по странам</a></span></li><li><span><a href="#Посетители-и-платящие-пользователи-в-разрезе-устройств" data-toc-modified-id="Посетители-и-платящие-пользователи-в-разрезе-устройств-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Посетители и платящие пользователи в разрезе устройств</a></span></li><li><span><a href="#Привлечение-посетителей-и-платящих-пользователей-в-разрезе-каналов" data-toc-modified-id="Привлечение-посетителей-и-платящих-пользователей-в-разрезе-каналов-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Привлечение посетителей и платящих пользователей в разрезе каналов</a></span></li><li><span><a href="#Пункты-3.2---3.4.-Визуализация-количества-платящих-пользователей-по-месяцам-и-финальные-выводы" data-toc-modified-id="Пункты-3.2---3.4.-Визуализация-количества-платящих-пользователей-по-месяцам-и-финальные-выводы-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Пункты 3.2 - 3.4. Визуализация количества платящих пользователей по месяцам и финальные выводы</a></span></li></ul></li><li><span><a href="#Маркетинг" data-toc-modified-id="Маркетинг-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Маркетинг</a></span><ul class="toc-item"><li><span><a href="#Расходы-по-времени-и-в-разрезе-источников" data-toc-modified-id="Расходы-по-времени-и-в-разрезе-источников-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Расходы по времени и в разрезе источников</a></span></li><li><span><a href="#Стоимость-привлечения-одного-покупателя-в-разрезе-источников" data-toc-modified-id="Стоимость-привлечения-одного-покупателя-в-разрезе-источников-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Стоимость привлечения одного покупателя в разрезе источников</a></span></li><li><span><a href="#Выводы-блока-&quot;Маркетинг&quot;" data-toc-modified-id="Выводы-блока-&quot;Маркетинг&quot;-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Выводы блока "Маркетинг"</a></span></li></ul></li><li><span><a href="#Окупаемость-рекламы-для-привлечения-пользователей" data-toc-modified-id="Окупаемость-рекламы-для-привлечения-пользователей-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Окупаемость рекламы для привлечения пользователей</a></span><ul class="toc-item"><li><span><a href="#Общая-окупаемость-рекламы" data-toc-modified-id="Общая-окупаемость-рекламы-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Общая окупаемость рекламы</a></span></li><li><span><a href="#Окупаемость-рекламы-с-разбивкой-по-устройствам" data-toc-modified-id="Окупаемость-рекламы-с-разбивкой-по-устройствам-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Окупаемость рекламы с разбивкой по устройствам</a></span></li><li><span><a href="#Окупаемость-рекламы-с-разбивкой-по-странам" data-toc-modified-id="Окупаемость-рекламы-с-разбивкой-по-странам-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Окупаемость рекламы с разбивкой по странам</a></span></li><li><span><a href="#Окупаемость-рекламы-с-разбивкой-по-рекламным-каналам" data-toc-modified-id="Окупаемость-рекламы-с-разбивкой-по-рекламным-каналам-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Окупаемость рекламы с разбивкой по рекламным каналам</a></span></li><li><span><a href="#Анализ-источников-TipTop-и-FaceBoom" data-toc-modified-id="Анализ-источников-TipTop-и-FaceBoom-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Анализ источников TipTop и FaceBoom</a></span></li><li><span><a href="#Анализ-удержания-по-основным-срезам" data-toc-modified-id="Анализ-удержания-по-основным-срезам-5.6"><span class="toc-item-num">5.6&nbsp;&nbsp;</span>Анализ удержания по основным срезам</a></span></li><li><span><a href="#Анализ-конверсии-по-основным-срезам" data-toc-modified-id="Анализ-конверсии-по-основным-срезам-5.7"><span class="toc-item-num">5.7&nbsp;&nbsp;</span>Анализ конверсии по основным срезам</a></span></li><li><span><a href="#Проверка-окупаемости-без-нерентабельных-источников" data-toc-modified-id="Проверка-окупаемости-без-нерентабельных-источников-5.8"><span class="toc-item-num">5.8&nbsp;&nbsp;</span>Проверка окупаемости без нерентабельных источников</a></span></li><li><span><a href="#Поиск-потенциала-среди-каналов-с-высоким-ROI" data-toc-modified-id="Поиск-потенциала-среди-каналов-с-высоким-ROI-5.9"><span class="toc-item-num">5.9&nbsp;&nbsp;</span>Поиск потенциала среди каналов с высоким ROI</a></span></li></ul></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Выводы</a></span><ul class="toc-item"><li><span><a href="#Причины-неокупаемости-пользователей" data-toc-modified-id="Причины-неокупаемости-пользователей-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Причины неокупаемости пользователей</a></span></li><li><span><a href="#Рекомендации-для-маркетинга" data-toc-modified-id="Рекомендации-для-маркетинга-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Рекомендации для маркетинга</a></span></li></ul></li></ul></div>

# %% [markdown]
# <strong>Описание данных:</strong>
#
# В распоряжении три датасета:
# * файл `visits_info_short.csv` хранит лог сервера с информацией о посещениях сайта
# * `orders_info_short.csv` — информацию о покупках
# * `costs_info_short.csv` — информацию о расходах на рекламу
#
# Структура visits_info_short.csv:
# * `User Id` — уникальный идентификатор пользователя
# * `Region` — страна пользователя
# * `Device` — тип устройства пользователя
# * `Channel` — идентификатор источника перехода
# * `Session Start` — дата и время начала сессии
# * `Session End` — дата и время окончания сессии
#
# Структура orders_info_short.csv
# * `User Id` — уникальный идентификатор пользователя
# * `Event Dt` — дата и время покупки
# * `Revenue` — сумма заказа
#
# Структура costs_info_short.csv
# * `Channel` — идентификатор рекламного источника
# * `Dt — дата` проведения рекламной кампании
# * `Costs` — расходы на эту кампанию

# %% [markdown]
# ## Загрузка и подготовка данных к анализу

# %% [markdown]
# Импорт библиотек:

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from datetime import datetime, timedelta
import numpy as np

# %% [markdown]
# Сохранение основных данных в переменные:

# %%
visits = pd.read_csv('/datasets/visits_info_short.csv')
orders = pd.read_csv('/datasets/orders_info_short.csv')
costs = pd.read_csv('/datasets/costs_info_short.csv')

# %% [markdown]
# Проверка данных на наличие корректность типов данных и наличие значений null:

# %%
visits.info()
orders.info()
costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   User Id        309901 non-null  int64
#  1   Region         309901 non-null  object
#  2   Device         309901 non-null  object
#  3   Channel        309901 non-null  object
#  4   Session Start  309901 non-null  object
#  5   Session End    309901 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   User Id   40212 non-null  int64
#  1   Event Dt  40212 non-null  object
#  2   Revenue   40212 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# ...

# %% [markdown]
# По первичным данным можно сделать следующие выводы:
# * в данных нет пропущенных значений
# * в таблице visits столбцы `Session Start` и `Session End` нужно перевести в формат даты
# * в таблице orders столбец `Event Dt` необходимо перевести в формат даты
# * в таблице costs столбец `dt` необходимо перевести в форматы даты, при этом формат должен содержать только дату без времени для корректной работы функции
# * во всех таблицах стоит скорректировать стиль записи

# %%
#Переводим нужные столбцы в формат даты:
visits['Session Start'] = pd.to_datetime(visits['Session Start'])
visits['Session End'] = pd.to_datetime(visits['Session End'])
orders['Event Dt'] = pd.to_datetime(orders['Event Dt'])
costs['dt'] = pd.to_datetime(costs['dt']).dt.date

#Корректируем стиль записи:
visits.columns = ['user_id', 'region', 'device', 'channel', 'session_start', 'session_end']
orders.columns = ['user_id', 'event_dt', 'revenue']
costs.columns = ['dt', 'channel', 'costs']

# %% [markdown]
# Дополнительно можно проверить адекватность данных:
# * Распределение длительности сессий из таблицы `visits`
# * Распределение расходов на рекламу из таблицы `costs`

# %%
visits['duration'] = (visits['session_end'] - visits['session_start']).dt.seconds
visits['duration'].hist(bins=50, figsize=(15,5))
plt.title('Распределение сессий по секундам')
plt.ylabel('Сессии')
None

# %% [markdown]
# В сессиях замечен пик около нуля. Данные распределены нормально, некоторые пользовательские сессии длились более 5 часов. Стоит дополнительно проверить данные на дубликаты:

# %%
visits.drop_duplicates().info()
orders.drop_duplicates().info()
costs.drop_duplicates().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 309901 entries, 0 to 309900
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   user_id        309901 non-null  int64
#  1   region         309901 non-null  object
#  2   device         309901 non-null  object
#  3   channel        309901 non-null  object
#  4   session_start  309901 non-null  datetime64[ns]
#  5   session_end    309901 non-null  datetime64[ns]
#  6   duration       309901 non-null  int64
# dtypes: datetime64[ns](2), int64(2), object(3)
# memory usage: 18.9+ MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   40212 non-null  int64
#  1   event_dt  40212 non-null  datetime64[ns]
#  2   revenue   40212 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# ...

# %% [markdown]
# Дубликатов не найдено

# %% [markdown]
# Итак, по результатам предобработки:
#
# * Данные проверены на наличие значений null, их не было выявлено
# * Формат дат переведен в корректный во всех 3-х таблицах
# * По длительности сессий не было выявлено аномалий
# * В данных не выявлено дубликатов

# %% [markdown]
# ## Функции для расчета и анализа LTV, ROI, удержания и конверсии

# %% [markdown]
# Функция для создания пользовательских профилей:

# %%
def get_profiles(sessions, orders, events, ad_costs, event_names=[]):

    # находим параметры первых посещений
    profiles = (
        sessions.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )

    # для когортного анализа определяем дату первого посещения
    # и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')

    # добавляем признак платящих пользователей
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())

    # добавляем флаги для всех событий из event_names
    for event in event_names:
        if event in events['event_name'].unique():
            profiles[event] = profiles['user_id'].isin(
                events.query('event_name == @event')['user_id'].unique()
            )

    # считаем количество уникальных пользователей
    # с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )

    # объединяем траты на рекламу и число привлечённых пользователей
    ad_costs = ad_costs.merge(new_users, on=['dt', 'channel'], how='left')

    # делим рекламные расходы на число привлечённых пользователей
    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']

    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        ad_costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )

    # стоимость привлечения органических пользователей равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)

    return profiles

# %% [markdown]
# Функция для расчёта удержания:

# %%
def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        sessions[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# Функция для расчёта конверсии:

# %%
def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# Функция для расчёта LTV и ROI:

# %%
def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        # собираем датафрейм с данными пользователей и значениями CAC, 
        # добавляя параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %% [markdown]
# Функция для сглаживания фрейма:

# %%
def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %% [markdown]
# Функция для визуализации удержания:

# %%
def plot_retention(retention, retention_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # в чётвертой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# Функция для визуализации конверсии:

# %%
def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# Функция для визуализации LTV и ROI:

# %%
def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(20, 10))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# В исследовательском анализе данных для ответов на вопросы будут использованы выгрузки таблиц. Дополнительно ответы на вопросы будут проиллюстрированы в графиках в отдельном пункте

# %% [markdown]
# ### Выгрузка пользователей и определение минимальной и максимальной даты привлечения пользователей

# %% [markdown]
# Выгрузка данных о профилях пользователей:

# %%
events = None
profiles = get_profiles(visits, orders, events, costs)

# %% [markdown]
# Определение минимальной и максимальной даты привлечения пользователей:

# %%
min_date = profiles['dt'].min()
max_date = profiles['dt'].max()

print('Самая ранняя дата привлечения пользователей -', min_date,
    ', cамая поздняя дата привлечения пользователей -', max_date)
# Out:
# Самая ранняя дата привлечения пользователей - 2019-05-01 , cамая поздняя дата привлечения пользователей - 2019-10-27

# %% [markdown]
# ### Посетители и платящие пользователи по странам

# %%
(profiles
 .groupby('region')
 .agg({'user_id' : 'nunique', 'payer' : ['sum', 'mean']})
 .droplevel(0, axis=1)
 .rename(columns={'nunique' : 'users', 'sum' : 'payers', 'mean': 'payers_share'})
 .sort_values(by='users', ascending=False)
)
# Out:
#                 users  payers  payers_share
# region
# United States  100002    6902      0.069019
# UK              17575     700      0.039829
# France          17450     663      0.037994
# Germany         14981     616      0.041119

# %% [markdown]
# По таблице можно сделать следующие выводы: больше всего пользователей и платящих пользователей наблюдается в `США`

# %% [markdown]
# ### Посетители и платящие пользователи в разрезе устройств

# %%
(profiles
 .groupby('device')
 .agg({'user_id' : 'nunique', 'payer' : ['sum', 'mean']})
 .droplevel(0, axis=1)
 .rename(columns={'nunique' : 'users', 'sum' : 'payers', 'mean': 'payers_share'})
 .sort_values(by='users', ascending=False)
)
# Out:
#          users  payers  payers_share
# device
# iPhone   54479    3382      0.062079
# Android  35032    2050      0.058518
# PC       30455    1537      0.050468
# Mac      30042    1912      0.063644

# %% [markdown]
# В абсолютном выражении лидирует устройство `iPhone` - с этого устройства пришло больше всего платящих пользователей. При этом самая доля платящих пользователей наблюдается у двух устройств - `Mac` и `iPhone`

# %% [markdown]
# ### Привлечение посетителей и платящих пользователей в разрезе каналов

# %%
(profiles
 .groupby('channel')
 .agg({'user_id' : 'nunique', 'payer' : ['sum', 'mean']})
 .droplevel(0, axis=1)
 .rename(columns={'nunique' : 'users', 'sum' : 'payers', 'mean': 'payers_share'})
 .sort_values(by='users', ascending=False)
)
# Out:
#                     users  payers  payers_share
# channel
# organic             56439    1160      0.020553
# FaceBoom            29144    3557      0.122049
# TipTop              19561    1878      0.096007
# OppleCreativeMedia   8605     233      0.027077
# LeapBob              8553     262      0.030633
# WahooNetBanner       8553     453      0.052964
# RocketSuperAds       4448     352      0.079137
# MediaTornado         4364     156      0.035747
# YRabbit              4312     165      0.038265
# AdNonSense           3880     440      0.113402
# lambdaMediaAds       2149     225      0.104700

# %% [markdown]
# * В абсолютном выражении больше всего платящих пользователей наблюдается у источника `FaceBoom`
# * Больше всего пользователей привлек органический трафик, однако по платящим пользователям он находится на 3-м месте из-за сравнительно невысокой доли платящих пользователей

# %% [markdown]
# ### Пункты 3.2 - 3.4. Визуализация количества платящих пользователей по месяцам и финальные выводы

# %%
plt.figure(figsize = (20, 15))

dimensions = ['region', 'device', 'channel']

for i, dimension in enumerate(dimensions):
    (profiles
     .pivot_table(index='month', columns=dimension, values='payer', aggfunc='sum')
     .plot(by=dimension, grid=True, ax=plt.subplot(2,2,i+1))
    )
    plt.title('Динамика платящих пользователей по срезу: ' + dimension)
    plt.ylabel('payers')

# %% [markdown]
# Итак, по динамике платящих пользователей можно сделать следующие выводы:
# * Среди регионов `США` лидирует во все месяцы. Количество платящих пользователей увеличивается почти во все месяцы
# * Среди девайсов `iPhone` лидирует с достаточно большим отрывом во все месяцы
# * Среди источников `FacebBoom` лидирует во все месяцы. `TipTop` находится на втором месте во все месяцы за исключением мая - в этом месяце `TipTop` был на 3-м месте
# * По всем срезам замечена просадка в июле и октябре - эти месяцы единственные, в которых наблюдается отток или стагнация количества платящих пользователей по сравнению с предыдущим месяцем у лидеров срезов: `США`, `iPhone`, `FaceBoom`

# %% [markdown]
# ## Маркетинг

# %% [markdown]
# ### Расходы по времени и в разрезе источников

# %% [markdown]
# Для начала уберем из таблицы с профилями пользователей органический трафик, чтобы не искажать данные:

# %%
profiles = profiles.query('channel != "organic"')

# %% [markdown]
# Подсчет затрат можно провести двумя способами. Использование этих двух способов может быть дополнительной проверкой

# %%
print(
    'Рекламные расходы из таблицы расходов составили'
    , costs['costs'].sum()
    , 'Из выгрузки профилей -' 
    , profiles['acquisition_cost'].sum()
     )
# Out:
# Рекламные расходы из таблицы расходов составили 105497.30000000002 Из выгрузки профилей - 105497.3

# %% [markdown]
# Можно переходить к подсчёту затрат по источникам трафика:

# %%
cost_by_channel = (profiles
                     .query('channel != "organic"')
                     .groupby('channel')
                     .agg({'acquisition_cost' : 'sum'})
                     .rename(columns={'acquisition_cost' : 'cost'})
                     .sort_values(by='cost', ascending=False)
                    )
cost_by_channel
# Out:
#                         cost
# channel
# TipTop              54751.30
# FaceBoom            32445.60
# WahooNetBanner       5151.00
# AdNonSense           3911.25
# OppleCreativeMedia   2151.25
# RocketSuperAds       1833.00
# LeapBob              1797.60
# lambdaMediaAds       1557.60
# MediaTornado          954.48
# YRabbit               944.22

# %%
cost_by_channel.plot(kind='bar', grid=True, figsize=(15,5))
plt.title('Расходы по источникам трафика')
None

# %% [markdown]
# По расходам лидирует источник `TipTop`, на втором месте - `FaceBoom`

# %% [markdown]
# Перейдём к исследованию динамики расходов по времени:

# %%
cost_by_date = (profiles
                 .query('channel != "organic"')
                 .groupby('dt')
                 .agg({'acquisition_cost' : 'sum'})
                 .rename(columns={'acquisition_cost' : 'cost'})
                 )

cost_by_date.plot(grid=True, figsize=(15,5))
plt.title('Расходы по дням')
None

# %% [markdown]
# График получился достаточно шумным, однако можно проследить явный тренд на увеличение расходов в течение периода. Для большей наглядности можно добавить скользящую среднюю

# %%
filter_data(cost_by_date,7).plot(grid=True, figsize=(15,5))
plt.title('Расходы по дням по скользящей средней 7')
plt.ylabel('cost')
None

# %% [markdown]
# Наибольшие расходы приходятся на период с октября 2019 года. По динамике наблюдаются характерные циклические колебания к началу месяца. Дополнительно можно проанализировать расходы по источникам трафика:

# %%
(profiles
 .loc[profiles['month'] != profiles['month'].max()]
 .pivot_table(index='month', columns='channel', values='acquisition_cost', aggfunc='sum')
 .rename(columns={'acquisition_cost' : 'cost'})
 .plot(by='channel', grid=True, figsize=(15,5))
)
plt.title('Расходы по каналам')
plt.ylabel('Расходы')
None

# %% [markdown]
# По графику можно увидеть, что расход расходов наблюдается у двух основных источников, которые принесли наибольше количество платящих пользователей: `TipTop` и `Faceboom`

# %% [markdown]
# ### Стоимость привлечения одного покупателя в разрезе источников

# %%
cost_per_user = profiles['acquisition_cost'].sum() / profiles['user_id'].count()
cost_per_payer = profiles['acquisition_cost'].sum() / profiles['payer'].sum()

print('Средняя цена за привлечение пользователя: ', cost_per_user,
      'Средняя цена за привлечение платящего пользователя:', cost_per_payer
     )
# Out:
# Средняя цена за привлечение пользователя:  1.1274813239427588 Средняя цена за привлечение платящего пользователя: 13.66368346069162

# %%
cac_by_channel = (
    profiles
     .groupby('channel')
     .agg({'acquisition_cost' : 'sum', 'user_id' : 'count', 'payer' : 'sum'})
     .rename(columns={'acquisition_cost' : 'cost', 'user_id' : 'users', 'payer' : 'payers'})
)

dimensions = ['users', 'payers']

plt.figure(figsize = (20, 10))
              
for i, dimension in enumerate(dimensions):              
    cac_by_channel['cost_per_' + dimension] = cac_by_channel['cost'] / cac_by_channel[dimension]
    (cac_by_channel['cost_per_' + dimension]
     .sort_values(ascending=False)
     .plot(kind='bar', grid=True, ax=plt.subplot(1,2,i+1)))
    plt.title('cost_per_' + dimension)
    None

# %%
cac_by_channel[['cost_per_users', 'cost_per_payers']].sort_values(by='cost_per_payers',ascending=False)
# Out:
#                     cost_per_users  cost_per_payers
# channel
# TipTop                    2.799003        29.154047
# WahooNetBanner            0.602245        11.370861
# OppleCreativeMedia        0.250000         9.232833
# FaceBoom                  1.113286         9.121619
# AdNonSense                1.008054         8.889205
# lambdaMediaAds            0.724802         6.922667
# LeapBob                   0.210172         6.861069
# MediaTornado              0.218717         6.118462
# YRabbit                   0.218975         5.722545
# RocketSuperAds            0.412095         5.207386

# %% [markdown]
# Итак:
# * наибольшая цена привлечения посетителя и платящего пользователя наблюдается у источника `TipTop`
# * `Faceboom`, который обеспечил наибольшее количество платящих пользователей, находится на 2-м месте по цене привлечения посетителя и на 4 по цене привелечения платящего пользователя

# %% [markdown]
# ### Выводы блока "Маркетинг"

# %% [markdown]
# * По данным наблюдается тренд на увеличение расходов по рекламе от месяца к месяцу
# * Увеличение расходов приходится, в основном, на источники `TipTop` и `Faceboom`
# * Наибольшие расходы и CAC наблюдаются у источника `TipTop`. CAC этого источника существенно превышает аналогичные показатели других источников
# * Лидером по количеству платящих пользователей остаётся `Faceboom`
#
# Уже сейчас можно сделать гипотезу о том, что эффективность `TipTop` может быть существенно ниже по сравнению с остальными рекламными каналами
#
# Для более точных выводов нужно перейти к следующему шагу - оценке окупаемости рекламы

# %% [markdown]
# ## Окупаемость рекламы для привлечения пользователей

# %% [markdown]
# Несмотря на то, что текущая дата - 1-го ноября 2019 года, последняя дата привлечения пользователя `max_date` приходится на 27 октября. Это значит, что в качестве параметра `observation_date` мы можем использовать максимально доступную дату привлечения. В ином случае в таблицы и графики попадут те пользователи, которые не успели "дожить" 14 дней

# %% [markdown]
# ### Общая окупаемость рекламы

# %%
obs_date = max_date
horizon = 14
ltv_raw, ltv_grouped, ltv_in_time, roi_grouped, roi_in_time = get_ltv(profiles, orders, obs_date, horizon)
plot_ltv_roi(ltv_grouped, ltv_in_time, roi_grouped, roi_in_time, horizon)

# %% [markdown]
# Можно сделать следующие выводы:
# * По графику ROI можно заметить, что реклама не окупается на 14 день
# * Раньше на 14 день реклама окупалась: до июля 2019 года окупаемость была положительной. Стоит заметить, что окупаемость снижалась в течение всего изучаемого периода
# * LTV пользователей на 14-й день достаточно стабилен. Нет предпосылок предполагать, что пользователи стали приносить меньше денег
# * Наблюдается увеличение CAC от месяца к месяцу. Между ROI и CAC наблюдается явная обратная взаимосвязь
#
# Итоговые первичные выводы: снижение рентабельности рекламы напрямую связано с увеличением стоимости привлечения пользователей

# %% [markdown]
# ### Окупаемость рекламы с разбивкой по устройствам

# %%
ltv_raw, ltv_grouped, ltv_in_time, roi_grouped, roi_in_time = (get_ltv(profiles
                                                                     , orders
                                                                     , obs_date
                                                                     , horizon
                                                                     , dimensions=['device'])
                                                              )
plot_ltv_roi(ltv_grouped, ltv_in_time, roi_grouped, roi_in_time, 14, window=14)

# %% [markdown]
# По графикам в разбивке на устройства можно сделать следующие выводы:
#
# * `PC` - единственное устройство, которое окупается на 14 день
# * Негативную динамику ROI можно увидеть по всем устройствам
# * Сильнее всего стоимость привлечения пользователей увеличилась по устройствам `iPhone` и `Mac`
#
# Итоговые первичные выводы: скорее всего, тип устройства - не основная причина неокупаемости рекламы. Окупаемость по устройствам может быть напрямую связана со стоимостью привлечения по основным источникам

# %% [markdown]
# ### Окупаемость рекламы с разбивкой по странам

# %%
ltv_raw, ltv_grouped, ltv_in_time, roi_grouped, roi_in_time = (get_ltv(profiles
                                                                     , orders
                                                                     , obs_date
                                                                     , horizon
                                                                     , dimensions=['region'])
                                                              )
plot_ltv_roi(ltv_grouped, ltv_in_time, roi_grouped, roi_in_time, 14, window=14)

# %% [markdown]
# По графикам в разбивке на страны можно сделать следующие выводы:
# * В США наблюдается самый высокий уровень LTV
# * США - единственый источник, который перестал окупаться в июне 2019 года. При этом основная причина неокупаемости - увеличение стоимости привлечения пользователей
#
# Итоговые первичные выводы: Одна из локализованных проблем - стоимость привлечения пользователей в США. Для более точных выводов следует также изучить источники привлечения трафика

# %% [markdown]
# ### Окупаемость рекламы с разбивкой по рекламным каналам

# %%
ltv_raw, ltv_grouped, ltv_in_time, roi_grouped, roi_in_time = (get_ltv(profiles
                                                                     , orders
                                                                     , obs_date
                                                                     , horizon
                                                                     , dimensions=['channel'])
                                                              )
plot_ltv_roi(ltv_grouped, ltv_in_time, roi_grouped, roi_in_time, 14, window=14)

# %% [markdown]
# В разбивке по источникам трафика можно сделать следующие выводы:
# * Ранее выдвинутая гипотеза о неокупаемости источника `TipTop` подтверждается: ранее мы заметили, что на этот источник приходится наибольшее количество расходов и наиболее высокий CAC. Можно увидеть зависимость между увеличением расходов на этот источник и снижением рентабельности
# * Среди нерентабельных каналов также замечен `FaceBoom` - лидер по количество привлеченных платящих пользователей
# * Дополнительно можно обратить внимание на источник `AdNoneSense`, который также не окупается. Стоит отметить, что этот источник не так сильно повлияет на общую рентабельность из-за относительно небольшой доли расходов и платящих пользователей
#
# Стоит уточнить срез и исследовать только источник `TipTop` и `FaceBoom` в разбивке по регионам

# %% [markdown]
# ### Анализ источников TipTop и FaceBoom

# %%
ltv_raw, ltv_grouped, ltv_in_time, roi_grouped, roi_in_time = (get_ltv(profiles.query('channel == "TipTop" or channel == "FaceBoom"')
                                                                     , orders
                                                                     , obs_date
                                                                     , horizon
                                                                     , dimensions=['channel', 'region'])
                                                              )
plot_ltv_roi(ltv_grouped, ltv_in_time, roi_grouped, roi_in_time, 14, window=14)

# %% [markdown]
# По двум нерентабельным источникам можно сделать следующие выводы:
# * Оба нерентабельных источника трафика (`TipTop` и `FaceBoom`) показывались только для пользователей США. Это объясняет, почему США - единственный регион, в котором не окупалась реклама
# * `Faceboom` был нерентабельным источником во все периоды времени со стабильным CAC, в `TipTop` же нерентабельность напрямую связана с увеличением стоимости привлечения
#
# Можно с уверенностью сказать, что увеличение стоимости привлечения пользователей в `TipTop` - основная причина неокупаемости рекламы
#
# Однако стоит также обратить внимание на `FaceBoom` - этот источник приносил наибольшее количество плательщиков из всех источников трафика, но, к сожалению, пользователи никогда не окупались в течение 14 дней. "Накопления" LTV у этого источника почти нет, то есть пользователи редко приносили деньги на 4-й и последующие дни жизни
#
# Дополнительно можно проанализировать удержание и конверсию, возможно, это даст больше информации:

# %% [markdown]
# ### Анализ удержания по основным срезам

# %%
retention_raw, retention_grouped, retention_in_time = get_retention(profiles
                                                                  , visits
                                                                  , obs_date
                                                                  , horizon
                                                                  , dimensions=['region'])
plot_retention(retention_grouped, retention_in_time, horizon, window=14)

# %%
retention_raw, retention_grouped, retention_in_time = get_retention(profiles
                                                                  , visits
                                                                  , obs_date
                                                                  , horizon
                                                                  , dimensions=['device'])
plot_retention(retention_grouped, retention_in_time, horizon, window=14)

# %%
retention_raw, retention_grouped, retention_in_time = get_retention(profiles
                                                                  , visits
                                                                  , obs_date
                                                                  , horizon
                                                                  , dimensions=['channel'])
plot_retention(retention_grouped, retention_in_time, horizon, window=14)

# %% [markdown]
# По выгрузке можно сделать важные выводы:
# * Среди источников наиболее низкие показатели удержания платящих пользователей наблюдаются у площадок `FaceBoom` и `AdNonSense`
# * В США наблюдается более низкий уровень удержания платящих пользователей по сравнению с другими странами. Скорее всего, это связано с низкими показателями удержания источника `FaceBoom`, который показывался только в США и принёс наибольшее количество платящих пользователей за период
#
# Дополнительно можно проанализировать конверсию по основным срезам:

# %% [markdown]
# ### Анализ конверсии по основным срезам

# %%
conversion_raw, conversion, conversion_history = get_conversion(profiles
                                                              , orders
                                                              , obs_date
                                                              , horizon
                                                              , dimensions=['region'])

plot_conversion(conversion, conversion_history, horizon, window=7)

# %%
conversion_raw, conversion, conversion_history = get_conversion(profiles
                                                              , orders
                                                              , obs_date
                                                              , horizon
                                                              , dimensions=['device'])

plot_conversion(conversion, conversion_history, horizon, window=7)

# %%
conversion_raw, conversion, conversion_history = get_conversion(profiles
                                                              , orders
                                                              , obs_date
                                                              , horizon
                                                              , dimensions=['channel'])

plot_conversion(conversion, conversion_history, horizon, window=7)

# %% [markdown]
# Сама динамика конверсии в отрыве от рентабельности малоинформативна почти для всех срезов, однако и здесь есть важные выводы, на которые стоит обратить внимание:
# * Несмотря на то, что удержание в `FaceBoom` находится на более низком уровне, чем по другим источникам, его конверсия - самая высокая
# * Близкие показатели и у источника `AdNonSense` - низкий уровень удержания и высокий процент конверсии
# * Удержание пользователей из США ниже по сравнению с другими регионами, а конверсия наоборот - выше. Скорее всего, основное влияние на конверсию США повлиял источник `FaceBoom` и `TipTop`
#
# Итак, вот что мы знаем про источник `FaceBoom`:
# * Это источник, который принес больше всего плательщиков
# * Его CAC находится на 2-м месте после `TipTop`
# * Его ROI во все месяцы был отрицательным
# * У этого источника был самый высокий уровень конверсии и самый низкий уровень удержания

# %% [markdown]
# ### Проверка окупаемости без нерентабельных источников

# %% [markdown]
# Дополнительно можно проверить, окупалась бы реклама в США без двух основных источников - `TipTop` и `Faceboom`:

# %%
ltv_raw, ltv_grouped, ltv_in_time, roi_grouped, roi_in_time = (get_ltv(profiles.query('channel != "TipTop" and channel != "FaceBoom"')
                                                                     , orders
                                                                     , obs_date
                                                                     , horizon
                                                                     , dimensions=['region'])
                                                              )
plot_ltv_roi(ltv_grouped, ltv_in_time, roi_grouped, roi_in_time, 14, window=14)

# %% [markdown]
# По графику можно увидеть, что рентабельность рекламы в США была бы существенно выше по сравнению с другими регионами. Однако стоит заметить, что `TipTop` и `FaceBoom` - источники, которые принесли наибольшее количество конверсий. Отключение этих источников существенно снизит объемы выручки

# %% [markdown]
# ### Поиск потенциала среди каналов с высоким ROI

# %% [markdown]
# В в течение периода также замечены источники с высоким ROI:
# * `MediaTornado`
# * `lambdaMediaAds`
# * `YRabbit`
#
# Дополнительно по ним можно также оценить динамику:

# %%
ltv_raw, ltv_grouped, ltv_in_time, roi_grouped, roi_in_time = (get_ltv(profiles.query('channel == "MediaTornado" or channel == "lambdaMediaAds" or channel == "YRabbit"')
                                                                     , orders
                                                                     , obs_date
                                                                     , horizon
                                                                     , dimensions=['channel', 'region'])
                                                              )
plot_ltv_roi(ltv_grouped, ltv_in_time, roi_grouped, roi_in_time, 14, window=14)

# %% [markdown]
# Вот интересные выводы, которые позволят найти потенциал для увеличения дохода:
#
# * Окупаемость источников `MediaTornado` и `YRabbit` была положительной в течение всего изучаемого периода
# * Источники `MediaTornado` и `YRabbit` работали только в регионе США

# %% [markdown]
# ## Выводы

# %% [markdown]
# ### Причины неокупаемости пользователей

# %% [markdown]
# Неокупаемость рекламы подтвердилась только в регионе США и только с июля 2019 года. В этом регионе замечены следующие причины нерентабельности:
#
# * Основная причина: увеличение стоимости привлечения пользователей в `TipTop`. При этом LTV пользователей не изменился существенно. Динамика CAC сделала ROI этого источника отрицательным. Так могло случиться, например, из-за повышения ставки за клик
# * Дополнительно: в США есть 2 источника с высоким процентом конверсии и низким относительно других источников уровнем удержания - `FaceBoom` и `AdNonSense`. Эти источники нерентабельны из-за низкого относительно других источников уровня LTV. Важно учесть, что в этих источниках показатели LTV в первый день были высокими в первый день, но "проигрывали" другим каналам по результатам 2 недель. Такое может происходить по многим причинам, например, в рекламных материалах пользователям предложили промокод, мотивирующий совершить недорогую покупку в 1-й день, но не мотивирующий пользоваться приложением в последующие дни

# %% [markdown]
# ### Рекомендации для маркетинга

# %% [markdown]
# Для увеличения рентабельности рекламы рекомендуем сделать следующие шаги:
#
# * Выявить причину роста CAC в `TipTip`. Возможно, стоит вернуться к тем рекламным настройкам мая 2019 года
# * Выяснить, с чем связан низкий уровень удержания и LTV источников `FaceBoom`. В первую очередь, нужно проверить рекламные материалы и настройки целевой аудитории
# * Дополнительно: протестировать рекламу `TipTip` в других регионах. Возможно, такой ход позволит компенсировать потери абсолютного количества плательщиков из-за грядущих изменений в рекламной стратегии
# * В США есть два перспективных источника `MediaTornado` и `YRabbit` со стабильно положительным ROI. Рекомендуем протестировать увеличение бюджета на эти источники в США, а также попробовать запустить в других регионах в случае наличия такой возможности
